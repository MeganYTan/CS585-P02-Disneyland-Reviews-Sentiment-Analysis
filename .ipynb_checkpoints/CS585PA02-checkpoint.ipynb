# %%
import pandas as pd
# train classifier
TRAIN_SIZE = 60 # size in percentage
TRAIN_SIZE_P = TRAIN_SIZE/100
# reading csv file 
df = pd.read_csv("DisneylandReviews.csv",  encoding='latin-1')
# examine contents
df.head()
# Out:
#    ï»¿Review_ID  Rating Year_Month     Reviewer_Location  \
# 0     670772142       4     2019-4             Australia
# 1     670682799       4     2019-5           Philippines
# 2     670623270       4     2019-4  United Arab Emirates
# 3     670607911       4     2019-4             Australia
# 4     670607296       4     2019-4        United Kingdom
#
#                                          Review_Text               Branch
# 0  If you've ever been to Disneyland anywhere you...  Disneyland_HongKong
# 1  Its been a while since d last time we visit HK...  Disneyland_HongKong
# 2  Thanks God it wasn   t too hot or too humid wh...  Disneyland_HongKong
# 3  HK Disneyland is a great compact park. Unfortu...  Disneyland_HongKong
# 4  the location is not in the city, took around 1...  Disneyland_HongKong

# %%
# step 0 data exploration and cleaning

# %%
df.shape
# Out:
# (42656, 6)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42656 entries, 0 to 42655
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ï»¿Review_ID       42656 non-null  int64
#  1   Rating             42656 non-null  int64
#  2   Year_Month         42656 non-null  object
#  3   Reviewer_Location  42656 non-null  object
#  4   Review_Text        42656 non-null  object
#  5   Branch             42656 non-null  object
# dtypes: int64(2), object(4)
# memory usage: 2.0+ MB

# %%
df['Rating'].value_counts()
# Out:
# Rating
# 5    23146
# 4    10775
# 3     5109
# 2     2127
# 1     1499
# Name: count, dtype: int64

# %%
# step 0.1 remove duplicates
df.drop_duplicates(keep='first', inplace=True)
df
# Out:
#        ï»¿Review_ID  Rating Year_Month     Reviewer_Location  \
# 0         670772142       4     2019-4             Australia
# 1         670682799       4     2019-5           Philippines
# 2         670623270       4     2019-4  United Arab Emirates
# 3         670607911       4     2019-4             Australia
# 4         670607296       4     2019-4        United Kingdom
# ...             ...     ...        ...                   ...
# 42651       1765031       5    missing        United Kingdom
# 42652       1659553       5    missing                Canada
# 42653       1645894       5    missing          South Africa
# 42654       1618637       4    missing         United States
# 42655       1536786       4    missing        United Kingdom
#
#                                              Review_Text               Branch
# 0      If you've ever been to Disneyland anywhere you...  Disneyland_HongKong
# 1      Its been a while since d last time we visit HK...  Disneyland_HongKong
# 2      Thanks God it wasn   t too hot or too humid wh...  Disneyland_HongKong
# 3      HK Disneyland is a great compact park. Unfortu...  Disneyland_HongKong
# 4      the location is not in the city, took around 1...  Disneyland_HongKong
# ...                                                  ...                  ...
# 42651  i went to disneyland paris in july 03 and thou...     Disneyland_Paris
# 42652  2 adults and 1 child of 11 visited Disneyland ...     Disneyland_Paris
# 42653  My eleven year old daughter and myself went to...     Disneyland_Paris
# 42654  This hotel, part of the Disneyland Paris compl...     Disneyland_Paris
# 42655  I went to the Disneyparis resort, in 1996, wit...     Disneyland_Paris
#
# [42644 rows x 6 columns]

# %%
# step 0.2 add sentiment column
def sentiment(score):
    if score > 3:
        return 1
    else:
        return 0
df['Sentiment'] = df['Rating'].apply(sentiment)

# %%
# step 0.3 remove stop words
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import pandas as pd

# Assuming df is your DataFrame and 'Review_Text' is your column

# Download stopwords
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\megta\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\megta\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
# Create a list of stopwords
stop_words = set(stopwords.words('english'))

def remove_stopwords(text):
    text = text.lower()
    word_tokens = word_tokenize(text)
    filtered_text = [word for word in word_tokens if word.lower() not in stop_words]
    return ' '.join(filtered_text)

# Apply the function to your DataFrame
df['Review_Text_No_Stopwords'] = df['Review_Text'].apply(remove_stopwords)
df
# Out:
#        ï»¿Review_ID  Rating Year_Month     Reviewer_Location  \
# 0         670772142       4     2019-4             Australia
# 1         670682799       4     2019-5           Philippines
# 2         670623270       4     2019-4  United Arab Emirates
# 3         670607911       4     2019-4             Australia
# 4         670607296       4     2019-4        United Kingdom
# ...             ...     ...        ...                   ...
# 42651       1765031       5    missing        United Kingdom
# 42652       1659553       5    missing                Canada
# 42653       1645894       5    missing          South Africa
# 42654       1618637       4    missing         United States
# 42655       1536786       4    missing        United Kingdom
#
#                                              Review_Text               Branch  \
# 0      If you've ever been to Disneyland anywhere you...  Disneyland_HongKong
# 1      Its been a while since d last time we visit HK...  Disneyland_HongKong
# 2      Thanks God it wasn   t too hot or too humid wh...  Disneyland_HongKong
# 3      HK Disneyland is a great compact park. Unfortu...  Disneyland_HongKong
# 4      the location is not in the city, took around 1...  Disneyland_HongKong
# ...                                                  ...                  ...
# 42651  i went to disneyland paris in july 03 and thou...     Disneyland_Paris
# 42652  2 adults and 1 child of 11 visited Disneyland ...     Disneyland_Paris
# 42653  My eleven year old daughter and myself went to...     Disneyland_Paris
# 42654  This hotel, part of the Disneyland Paris compl...     Disneyland_Paris
# 42655  I went to the Disneyparis resort, in 1996, wit...     Disneyland_Paris
#
#        Sentiment                           Review_Text_No_Stopwords
# 0              1  've ever disneyland anywhere 'll find disneyla...
# 1              1  since last time visit hk disneyland .. yet , t...
# 2              1  thanks god hot humid visiting park otherwise w...
# 3              1  hk disneyland great compact park . unfortunate...
# 4              1  location city , took around 1 hour kowlon , ki...
# ...          ...                                                ...
# 42651          1  went disneyland paris july 03 thought brillian...
# 42652          1  2 adults 1 child 11 visited disneyland paris b...
# 42653          1  eleven year old daughter went visit son london...
# 42654          1  hotel , part disneyland paris complex , wonder...
# 42655          1  went disneyparis resort , 1996 , small child ....
#
# [42644 rows x 8 columns]

# %%
# Step 0 split into training and test set
training_set = df.iloc[:int(len(df) * TRAIN_SIZE_P)]
training_set
# Out:
#        ï»¿Review_ID  Rating Year_Month     Reviewer_Location  \
# 0         670772142       4     2019-4             Australia
# 1         670682799       4     2019-5           Philippines
# 2         670623270       4     2019-4  United Arab Emirates
# 3         670607911       4     2019-4             Australia
# 4         670607296       4     2019-4        United Kingdom
# ...             ...     ...        ...                   ...
# 25592     143628886       5    2012-10         United States
# 25593     143622277       5     2012-9         United States
# 25594     143618949       5    2012-10         United States
# 25595     143576957       3     2012-9           New Zealand
# 25596     143575743       5    2012-10         United States
#
#                                              Review_Text  \
# 0      If you've ever been to Disneyland anywhere you...
# 1      Its been a while since d last time we visit HK...
# 2      Thanks God it wasn   t too hot or too humid wh...
# 3      HK Disneyland is a great compact park. Unfortu...
# 4      the location is not in the city, took around 1...
# ...                                                  ...
# 25592  Disneyland is truly the Happiest place on eart...
# 25593  I have been going to Disneyland the last week ...
# 25594  We are annual pass holders and love everything...
# 25595  Not as many rides as I expected to it to have ...
# 25596  The musical parade was a hit with my kids. If ...
#
#                       Branch  Sentiment  \
# 0        Disneyland_HongKong          1
# 1        Disneyland_HongKong          1
# 2        Disneyland_HongKong          1
# 3        Disneyland_HongKong          1
# 4        Disneyland_HongKong          1
# ...                      ...        ...
# 25592  Disneyland_California          1
# 25593  Disneyland_California          1
# 25594  Disneyland_California          1
# 25595  Disneyland_California          0
# 25596  Disneyland_California          1
#
#                                 Review_Text_No_Stopwords
# 0      've ever disneyland anywhere 'll find disneyla...
# 1      since last time visit hk disneyland .. yet , t...
# 2      thanks god hot humid visiting park otherwise w...
# 3      hk disneyland great compact park . unfortunate...
# 4      location city , took around 1 hour kowlon , ki...
# ...                                                  ...
# 25592  disneyland truly happiest place earth ! second...
# 25593  going disneyland last week september many year...
# 25594  annual pass holders love everything disney . v...
# 25595  many rides expected honest . great kiddies tho...
# 25596  musical parade hit kids . love disneyland abso...
#
# [25586 rows x 8 columns]

# %%
# test set is last 20%
test_set = df.iloc[int(len(df) * 0.8):]
test_set
# Out:
#        ï»¿Review_ID  Rating Year_Month Reviewer_Location  \
# 34126     367396496       3     2016-4        Luxembourg
# 34127     367388148       1     2016-4    United Kingdom
# 34128     367371478       3     2016-3     United States
# 34129     367304021       3     2016-4    United Kingdom
# 34130     367255494       5     2016-4    United Kingdom
# ...             ...     ...        ...               ...
# 42651       1765031       5    missing    United Kingdom
# 42652       1659553       5    missing            Canada
# 42653       1645894       5    missing      South Africa
# 42654       1618637       4    missing     United States
# 42655       1536786       4    missing    United Kingdom
#
#                                              Review_Text            Branch  \
# 34126  My best Friend and I are huge Disney Fans sinc...  Disneyland_Paris
# 34127  I stayed at Disneyland Paris from 5 4 2016   9...  Disneyland_Paris
# 34128  This is a hard review to write. Being the Disn...  Disneyland_Paris
# 34129  We have just returned from Disneyland Paris wi...  Disneyland_Paris
# 34130  was sceptical about my enjoyment of disney wen...  Disneyland_Paris
# ...                                                  ...               ...
# 42651  i went to disneyland paris in july 03 and thou...  Disneyland_Paris
# 42652  2 adults and 1 child of 11 visited Disneyland ...  Disneyland_Paris
# 42653  My eleven year old daughter and myself went to...  Disneyland_Paris
# 42654  This hotel, part of the Disneyland Paris compl...  Disneyland_Paris
# 42655  I went to the Disneyparis resort, in 1996, wit...  Disneyland_Paris
#
#        Sentiment                           Review_Text_No_Stopwords
# 34126          0  best friend huge disney fans since little . vi...
# 34127          0  stayed disneyland paris 5 4 2016 9 4 2016. gro...
# 34128          0  hard review write . disney enthusiast . let st...
# 34129          0  returned disneyland paris eight month old baby...
# 34130          1  sceptical enjoyment disney went mainly grand c...
# ...          ...                                                ...
# 42651          1  went disneyland paris july 03 thought brillian...
# 42652          1  2 adults 1 child 11 visited disneyland paris b...
# 42653          1  eleven year old daughter went visit son london...
# 42654          1  hotel , part disneyland paris complex , wonder...
# 42655          1  went disneyparis resort , 1996 , small child ....
#
# [8529 rows x 8 columns]

# %%
# step 1 get vocabulary in training set
vocabulary = training_set['Review_Text_No_Stopwords'].str.split(expand=True).stack().unique().tolist()
vocabulary = [word.lower() for word in vocabulary]
# Print the vocabulary
vocabulary
# Out:
# ["'ve",
#  'ever',
#  'disneyland',
#  'anywhere',
#  "'ll",
#  'find',
#  'hong',
#  'kong',
#  'similar',
#  'layout',
#  'walk',
#  'main',
#  'street',
#  '!',
#  'familiar',
#  'feel',
#  '.',
#  'one',
#  'rides',
#  'small',
#  'world',
#  'absolutely',
#  'fabulous',
#  'worth',
#  'day',
#  'visited',
#  'fairly',
#  'hot',
#  'relatively',
#  'busy',
#  'queues',
#  'moved',
#  'well',
#  'since',
#  'last',
#  'time',
#  'visit',
#  'hk',
#  '..',
#  'yet',
#  ',',
#  'stay',
#  'tomorrowland',
#  'aka',
#  'marvel',
#  'land',
#  'iron',
#  'man',
#  'experience',
#  'n',
#  'newly',
#  'open',
#  'ant',
#  'wasp',
#  'ironman',
#  'great',
#  'feature',
#  'exciting',
#  'especially',
#  'whole',
#  'scenery',
#  '(',
#  'central',
#  'area',
#  'kowloon',
#  ')',
#  'antman',
#  'changed',
#  'previous',
#  'buzz',
#  'lightyear',
#  'less',
#  "'m",
#  'expecting',
#  'something',
#  'however',
#  'boys',
#  'like',
#  'space',
#  'mountain',
#  'turns',
#  'star',
#  'wars',
#  '1',
#  'cast',
#  'members',
#  'staffs',
#  'felt',
#  'bit',
#  'minus',
#  'point',
#  'dun',
#  'disney',
#  'brand',
#  'seems',
#  'local',
#  'ocean',
#  'park',
#  'even',
#  'worst',
#  'got',
#  'smiling',
#  'face',
#  'wan',
#  'na',
#  'u',
#  'enter',
#  'attraction',
#  'leave',
#  'hello',
#  'supposed',
#  'happiest',
#  'place',
#  'earth',
#  'really',
#  'dont',
#  'bakery',
#  'attractive',
#  'delicacies',
#  'theme',
#  'sweets',
#  'good',
#  'points',
#  'also',
#  'starbucks',
#  'inside',
#  'thanks',
#  'god',
#  'humid',
#  'visiting',
#  'otherwise',
#  'would',
#  'big',
#  'issue',
#  'lot',
#  'shade',
#  '.i',
#  'arrived',
#  'around',
#  '10:30am',
#  'left',
#  '6pm',
#  'unfortunately',
#  'evening',
#  'parade',
#  '8.5',
#  'hours',
#  'much',
#  'me.there',
#  'plenty',
#  'everyone',
#  'interesting',
#  'enjoy.it',
#  'extremely',
#  'longest',
#  'queue',
#  'certain',
#  'attractions',
#  '45',
#  'minutes',
#  'bad',
#  '.although',
#  'amazing',
#  'underwhelmed',
#  'choice',
#  'quite',
#  'grand',
#  'castle',
#  'closed',
#  'way',
#  '.the',
#  'food',
#  'options',
#  'coffee',
#  'shops',
#  'including',
#  'gift',
#  'toilets',
#  'everywhere.all',
#  'together',
#  'enjoyed',
#  'compact',
#  'maintenance',
#  'work',
#  'going',
#  'present',
#  'number',
#  'areas',
#  'famous',
#  'go',
#  'midweek',
#  'crowded',
#  'certainly',
#  'near',
#  'bus',
#  'la',
#  'notice',
#  'prices',
#  'drinks',
#  'etc',
#  'gone',
#  'roof',
#  'prepared',
#  'pay',
#  'top',
#  'dollar',
#  'snacks',
#  'avoid',
#  'souvenir',
#  'regardless',
#  'kids',
#  'love',
#  'location',
#  'city',
#  'took',
#  'hour',
#  'kowlon',
#  'everything',
#  'fine',
#  'anaheim',
#  'tokyo',
#  'called',
#  'souvenirs',
#  'entrance',
#  'tickets',
#  'slightly',
#  'expensive',
#  'basically',
#  'children',
#  'people',
#  'never',
#  'choices',
#  'acceptable',
#  'mostly',
#  'fast',
#  'bottled',
#  'water',
#  'fountains',
#  'refill',
#  'bottles',
#  'pretty',
#  'problem',
#  'rude',
#  'pushing',
#  'shoving',
#  'cutting',
#  'lines',
#  'stands',
#  'take',
#  'forget',
#  'trying',
#  'see',
#  'shows',
#  'free',
#  'seats',
#  "n't",
#  'let',
#  'happen',
#  'far',
#  'managed',
#  'property',
#  'wo',
#  'know',
#  'obviously',
#  'went',
#  'daughter',
#  'loved',
#  'canceled',
#  'though',
#  'think',
#  'intro',
#  'magic',
#  'little',
#  'ones',
#  'almost',
#  'completed',
#  '1.5days.one',
#  'drawback',
#  'timing',
#  'example',
#  "'s",
#  'storybook',
#  'theatre',
#  'wed',
#  'thu',
#  'private',
#  'events',
#  'restaurants',
#  'close',
#  'mid',
#  'week',
#  'tue',
#  'thur',
#  'best',
#  'plan',
#  'week.the',
#  'biggest',
#  'disappointment',
#  'maxim',
#  'decent',
#  'restaurant',
#  'corner',
#  'cafe',
#  'typical',
#  'abrupt',
#  'hongkong',
#  'style',
#  'service',
#  'serving',
#  'staff',
#  'train',
#  'fantastic',
#  'get',
#  'past',
#  'station',
#  'signage',
#  'terrible',
#  'want',
#  'rainning',
#  'working',
#  'could',
#  'map',
#  'priced',
#  'fun',
#  'characters',
#  '2',
#  'seen',
#  'cabana',
#  'photos',
#  'visitors',
#  'queuing',
#  'rain',
#  'waste',
#  'money',
#  'walt',
#  'horrified',
#  'enough',
#  'eating',
#  'places',
#  'amount',
#  'rest',
#  'rooms',
#  'building',
#  'knows',
#  'atmosphere',
#  'fantasy',
#  'talking',
#  'whatever',
#  'say',
#  'childhood',
#  'dreams',
#  'come',
#  'true',
#  'starting',
#  'environment',
#  'popcorn',
#  'mtr',
#  'trains',
#  'specially',
#  'designed',
#  'opinion',
#  'two',
#  'ticket',
#  'explore',
#  'else',
#  'may',
#  'remain',
#  'incomplete',
#  'online',
#  'save',
#  'hkd',
#  '100',
#  'comparison',
#  'spot',
#  'must',
#  'miss',
#  'include',
#  'jungle',
#  'river',
#  'cruise',
#  'micky',
#  'phillhar',
#  '4d',
#  'show',
#  'lion',
#  'king',
#  'showit',
#  'better',
#  'home',
#  'regarding',
#  'timings',
#  'maximise',
#  'cover',
#  'sundays',
#  'public',
#  'holidays',
#  'rush',
#  'cease',
#  'amaze',
#  'florida',
#  'thought',
#  'exhausted',
#  'kid',
#  'nope',
#  'still',
#  'dl',
#  'bucketlist',
#  'spent',
#  'grown',
#  'admit',
#  'tire',
#  'many',
#  'states',
#  'parks',
#  'haunted',
#  'house',
#  'catch',
#  'list',
#  'lots',
#  'spend',
#  'course',
#  'days',
#  'second',
#  'early',
#  'straight',
#  'back',
#  'lineups',
#  'twice',
#  'row',
#  'suitable',
#  'young',
#  '7,6,5,4,3',
#  'disappointing',
#  'nightly',
#  'fireworks',
#  'season',
#  'indeed',
#  'family',
#  'made',
#  'birthday',
#  'memorable',
#  'huge',
#  'definately',
#  'need',
#  '3',
#  'aged',
#  '11',
#  '9',
#  '&',
#  '6',
#  'variety',
#  'ages',
#  '3d',
#  'models',
#  'ordering',
#  'helpful',
#  'awesome',
#  'brought',
#  'price',
#  '1.',
#  'advise',
#  'look',
#  'deal',
#  'due',
#  'refurbished',
#  'altered',
#  'weekday',
#  'aprox',
#  '30',
#  'min',
#  'wait',
#  'recommend',
#  'weekends',
#  'said',
#  'general',
#  'drink',
#  '.this',
#  'easily',
#  'done',
#  'pass',
#  '...',
#  'scenes',
#  'movies',
#  'fairytales',
#  '8',
#  'pm',
#  'character',
#  '60',
#  'per',
#  'person',
#  'eat',
#  'cost',
#  'fortune',
#  'assume',
#  'us',
#  'half',
#  'ride',
#  'construction',
#  'finished',
#  'soon',
#  'track',
#  'single',
#  'rider',
#  'faster',
#  'average',
#  'reviewing',
#  'speaks',
#  'smaller',
#  'expected',
#  'nothing',
#  'except',
#  'become',
#  'child',
#  'step',
#  'easy',
#  'dedicated',
#  'trams',
#  'subway',
#  'stations',
#  'sunset',
#  'definitely',
#  'waiting',
#  'bought',
#  'tourist',
#  'via',
#  'klook',
#  'value',
#  'bearings',
#  'missed',
#  'favourite',
#  'means',
#  'queuing.the',
#  'parades',
#  'saw',
#  'moana',
#  'mickey',
#  'wondrous',
#  'book',
#  'works',
#  'visible',
#  'magical',
#  'first',
#  'fan',
#  'live',
#  '20',
#  'california',
#  '10',
#  'years',
#  'vacation',
#  'able',
#  'getting',
#  'downtown',
#  'super',
#  'impressed',
#  'takes',
#  'decked',
#  'themes',
#  'next',
#  'okay',
#  'compared',
#  'kinda',
#  'sucks',
#  'run',
#  'wednesday',
#  'slow',
#  'please',
#  'idea',
#  'nice',
#  'thrill',
#  'seekers',
#  'tip',
#  'make',
#  'sure',
#  'read',
#  'description',
#  'line',
#  'life',
#  'wounderous',
#  'new',
#  'four',
#  'year',
#  'old',
#  'pubs',
#  'afraid',
#  'loud',
#  'noises',
#  '12',
#  'probably',
#  'major',
#  'overall',
#  'beautiful',
#  'wonderful',
#  'buy',
#  'teacup',
#  'standard',
#  'chinese',
#  'reasonable',
#  'adults',
#  'roller',
#  'coasters',
#  'disappointed',
#  'flat',
#  'enjoyable',
#  'disneylands',
#  'region',
#  'sleeping',
#  'beauty',
#  'renovation',
#  'pictures',
#  'taken',
#  'square',
#  'appealing',
#  'scaffolding',
#  'sight',
#  'signboards',
#  'donald',
#  'duck',
#  'photo',
#  'paid',
#  'available',
#  'price.tomorrow',
#  'excellent',
#  'twice.philar',
#  'awesome.fantasy',
#  'rides.adventure',
#  'opportunities',
#  'tarzan',
#  'treetop',
#  'boat',
#  'kids.grizzly',
#  'gulch',
#  'favourites',
#  'coaster',
#  '15',
#  'minute',
#  'generic',
#  'apart',
#  'language',
#  'different',
#  'others',
#  'shame',
#  'trip',
#  'ago',
#  'smallish',
#  'high',
#  'outdoor',
#  'clean',
#  'tidy',
#  'qualify',
#  'ie',
#  'served',
#  'warm',
#  'cold',
#  'vegetarian',
#  'options.the',
#  'virtually',
#  'non',
#  'existent',
#  'minutesoverall',
#  'entry',
#  'comparatively',
#  'inexpensive',
#  'times',
#  'already',
#  '?',
#  'chicken',
#  'try',
#  'visits',
#  'finally',
#  'courage',
#  'ended',
#  'loving',
#  'grizzly',
#  'scary',
#  'opening',
#  'found',
#  'short',
#  'wanted',
#  'afternoon',
#  'renovated',
#  'decided',
#  '8th',
#  'kiddy',
#  'enjoy',
#  'equates',
#  '$',
#  'aud',
#  'bottle',
#  'burger',
#  'combo',
#  'meal',
#  'equated',
#  '22',
#  'stayed',
#  'hollywood',
#  'hotel',
#  'balls',
#  'charge',
#  'insane',
#  '120',
#  'buffet',
#  'dinner',
#  '55',
#  'breakfast',
#  'cafes',
#  'supermarkets',
#  'nearby',
#  'grab',
#  'snack',
#  'cheap',
#  'unless',
#  'travelling',
#  'thru',
#  'china',
#  'weeks',
#  'crazy',
#  'crappy',
#  'deep',
#  'fried',
#  'flavourless',
#  'bowl',
#  'lettuce',
#  'salad',
#  'vouchers',
#  'stating',
#  'st',
#  '%',
#  'discount',
#  '1030',
#  'told',
#  'false',
#  'advertising',
#  'toy',
#  'story',
#  'insanely',
#  'sun',
#  'bouncing',
#  'light',
#  'concrete',
#  'husband',
#  'actually',
#  'hypo',
#  'coz',
#  'surely',
#  'put',
#  'camo',
#  'shades',
#  'parents',
#  'elderly',
#  'astray',
#  'either',
#  '900',
#  'poorer',
#  'note',
#  ':',
#  'five',
#  'fault',
#  'anything',
#  'hire',
#  'pram',
#  'pinched',
#  'quickly',
#  'replaced',
#  'hotels',
#  'makes',
#  'easier',
#  'adults.we',
#  "'re",
#  'couple',
#  'selection',
#  'foods',
#  'caramel',
#  'bars',
#  'available.the',
#  'shopping',
#  'highlight',
#  'gifts',
#  'clothing',
#  'daily',
#  'special',
#  'sell',
#  'bring',
#  'hats',
#  'umbrella',
#  'trepidation',
#  'months',
#  'previously.no',
#  'needed',
#  'hkdl',
#  'it.yes',
#  'paced',
#  'none',
#  'anaheim.we',
#  'large',
#  'amounts',
#  'numbers',
#  'ups',
#  '5',
#  'held',
#  '3pm',
#  "'d",
#  'started',
#  'huddled',
#  'umbrellas',
#  'undercover',
#  'over.i',
#  'totally',
#  'keep',
#  'mind',
#  'slower',
#  'hyperspace',
#  'car',
#  'shanghai',
#  'every',
#  'sea',
#  'walking',
#  'gates',
#  'owned',
#  'government',
#  'quietness',
#  'morning',
#  'things',
#  '10am',
#  'front',
#  'storyland',
#  '11am',
#  'purchased',
#  'australia',
#  'printed',
#  'sent',
#  'email',
#  'link',
#  'electronic',
#  'version',
#  'qr',
#  'codes',
#  'personalised',
#  'used',
#  'website',
#  'dining',
#  'entitled',
#  'lunch',
#  'iceblock',
#  'double',
#  'purchase',
#  'uses',
#  'system',
#  'scan',
#  'fastpass',
#  'staying',
#  'explorers',
#  'lodge',
#  'received',
#  'passes',
#  'aimed',
#  'asian',
#  'market',
#  'although',
#  'serve',
#  'burgers',
#  'fussy',
#  'eaters',
#  'beware',
#  'limited',
#  'quality',
#  'ate',
#  'starliner',
#  'tomorrowland.we',
#  'overlay',
#  'sooo',
#  'coool',
#  'pirates',
#  'caribbean',
#  'sad',
#  'philharmagic',
#  'fun.unique',
#  'mystic',
#  'manor',
#  'trackless',
#  'three',
#  'runaway',
#  'mine',
#  'cars',
#  'varies',
#  'depending',
#  'sitting',
#  'rough',
#  'unique',
#  'simulator',
#  'stark',
#  'industries',
#  'flyer',
#  'fun.when',
#  'remember',
#  'choose',
#  'english',
#  'cantonese',
#  'skippers',
#  'script',
#  'difference',
#  'hkl',
#  'allows',
#  'break',
#  'net',
#  'speed',
#  'girls',
#  '17',
#  'attended',
#  'christmas',
#  'decorations',
#  'great.hk',
#  'change',
#  'sunny',
#  'bay',
#  'use',
#  'octopus',
#  'card',
#  'travel',
#  'shuttle',
#  'buses',
#  'transport',
#  'hub',
#  'along',
#  'roughly',
#  'ferry',
#  'runs',
#  'option',
#  'shaped',
#  'windows',
#  'theming',
#  'carriages',
#  'australian',
#  'full',
#  'see.if',
#  'chance',
#  'experiences',
#  'enjoyed.for',
#  'unexpected',
#  'rc',
#  'racer',
#  'toystoryland',
#  'wait.for',
#  'families',
#  'younger',
#  'heaps',
#  'kind',
#  'skipped',
#  'fantasyland',
#  'here.the',
#  'navigable',
#  'simple',
#  'mong',
#  'cok',
#  'discounted',
#  'rate',
#  'thai',
#  'bank',
#  'centre',
#  'nathan',
#  'road',
#  'right',
#  'kok',
#  'level',
#  '4',
#  'numerous',
#  'cts',
#  'reviews',
#  'asked',
#  'cheapest',
#  '557hkd',
#  'asking',
#  'shop',
#  'seem',
#  'sales',
#  'advisor',
#  'hand',
#  'letter',
#  'box',
#  'office',
#  'swap',
#  'problems',
#  'roadas',
#  'opened',
#  '10.30am',
#  'taxi',
#  'costs',
#  '200hkd',
#  'minutes.on',
#  'route',
#  'pink',
#  'lai',
#  'orange',
#  'red',
#  '20hkd',
#  ';',
#  'arriving',
#  'heavily',
#  'stop',
#  'crowds',
#  'ghost',
#  ...]

# %%
# step 2 get bag of words
from scipy.sparse import lil_matrix

# Assuming 'vocabulary' is a list of unique words
vocabulary_index = {word: i for i, word in enumerate(vocabulary)}

# Create a function to create a binary bag of words using a sparse matrix
def create_sparse_binary_bag_of_words(text, vocabulary_index):
    # Initialize a sparse matrix with dimensions (1, len(vocabulary))
    bag_of_words_sparse = lil_matrix((1, len(vocabulary_index)))
    words = word_tokenize(text)
    for word in words:
        if word in vocabulary_index:
            bag_of_words_sparse[0, vocabulary_index[word]] = 1
    return bag_of_words_sparse

# Apply the function to each review in your training set
# This will create a list of sparse matrices (one for each review)
sparse_bows = training_set['Review_Text_No_Stopwords'].apply(lambda x: create_sparse_binary_bag_of_words(x, vocabulary_index))

# Now, you can combine these into a single sparse matrix
from scipy.sparse import vstack
X_train = vstack(sparse_bows)

# %%
from sklearn.feature_extraction.text import CountVectorizer
import pandas as pd
# WE DON"T NEED THIS?
# Assuming training_set is your DataFrame and 'Review_Text_No_Stopwords' contains the preprocessed text

# Initialize CountVectorizer with binary=True to get a binary Bag of Words model
vectorizer = CountVectorizer(binary=True, vocabulary=vocabulary)

# Fit and transform the preprocessed texts
X_train = vectorizer.fit_transform(training_set['Review_Text_No_Stopwords'])
X_train
# Out:
# <25586x39941 sparse matrix of type '<class 'numpy.int64'>'
# 	with 1187516 stored elements in Compressed Sparse Row format>

# %%
y_train = training_set['Sentiment']
y_train
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 25592    1
# 25593    1
# 25594    1
# 25595    0
# 25596    1
# Name: Sentiment, Length: 25586, dtype: int64

# %%
y_train_array = y_train.to_numpy() if hasattr(y_train, 'to_numpy') else y_train
y_train_array
# Out:
# array([1, 1, 1, ..., 1, 0, 1], dtype=int64)

# %%
# step 3 construct model
## P(positive)
## p(negative)
num_rows = len(training_set)
num_rows_positive = (training_set['Sentiment'] == 1).sum()
num_rows_negative = (training_set['Sentiment'] == 0).sum()
probability_positive = num_rows_positive/num_rows
probability_negative = num_rows_negative/num_rows
probability_positive, probability_negative
# Out:
# (0.830024232001876, 0.16997576799812397)

# %%
# for each word and label get probability =  ((count x = X and y = Y)+1) / (count(number of words when y = Y) + # of words in Vocabulary)

# %%
df['Word_Count'] = df['Review_Text_No_Stopwords'].apply(lambda x: len(word_tokenize(x)))
word_count_by_y = df.groupby('Sentiment')['Word_Count'].sum()
word_count_by_y
# Out:
# Sentiment
# 0     908769
# 1    2538198
# Name: Word_Count, dtype: int64

# %%
# Convert to COO format for easier iteration over non-zero elements
import numpy as np
X_train_coo = X_train.tocoo()
feature_counts_positive = np.zeros(X_train.shape[1])
feature_counts_negative = np.zeros(X_train.shape[1])

for i, j, v in zip(X_train_coo.row, X_train_coo.col, X_train_coo.data):
    if y_train_array[i] == 0:
        feature_counts_negative[j] += v
    else:
        feature_counts_positive[j] += v

# Calculate likelihoods with Laplace smoothing --  this is numpy array
feature_counts_negative = feature_counts_negative + 1
feature_counts_positive = feature_counts_positive + 1
likelihoods_negative = (feature_counts_negative) / (word_count_by_y[0] +  len(vocabulary_index))
likelihoods_positive = (feature_counts_positive) / (word_count_by_y[1] +  len(vocabulary_index))
# each number is probability(x = word<corresponding to index of col in X_train> | y = positive/negative)
likelihoods_positive,likelihoods_negative
# Out:
# (array([4.55367224e-04, 3.80507025e-04, 4.13437755e-03, ...,
#         7.75753363e-07, 7.75753363e-07, 7.75753363e-07]),
#  array([3.85787016e-04, 2.79326665e-04, 2.34528992e-03, ...,
#         1.05406289e-06, 1.05406289e-06, 1.05406289e-06]))

# %%
# prediction
def predict(X_new, probability_negative, probability_positive, likelihoods_negative, likelihoods_positive):
    # Ensure X_new is in COO format
    X_new_coo = X_new.tocoo()
    predictions = np.zeros(X_new.shape[0])
    
    # Log probabilities for numerical stability
    log_probability_negative = np.log(probability_negative)
    log_probability_positive = np.log(probability_positive)
    log_likelihoods_negative = np.log(likelihoods_negative)
    log_likelihoods_positive = np.log(likelihoods_positive)

    # Calculate log posterior probabilities
    for i in range(X_new.shape[0]):
        log_posterior_prob_0 = log_probability_negative
        log_posterior_prob_1 = log_probability_positive
        
        for j in range(X_new_coo.nnz):
            if X_new_coo.row[j] == i:
                feature_index = X_new_coo.col[j]
                log_posterior_prob_0 += log_likelihoods_negative[feature_index]
                log_posterior_prob_1 += log_likelihoods_positive[feature_index]
                
        # Classification based on higher log posterior probability
        predictions[i] = 1 if log_posterior_prob_1 > log_posterior_prob_0 else 0
        
    return predictions

# %%
X_test = vectorizer.fit_transform(test_set['Review_Text_No_Stopwords'])
y_pred_manual = predict(X_test, probability_negative, probability_positive, likelihoods_negative, likelihoods_positive)
y_pred_manual
# Out:
# array([1., 1., 1., ..., 1., 1., 1.])

# %%
# Calculate and print the accuracy
from sklearn.metrics import accuracy_score
y_test = test_set['Sentiment']
accuracy = accuracy_score(y_test, y_pred_manual)
print(f'Accuracy: {accuracy}')
# Out:
# Accuracy: 0.7071168952983937

# %%
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns
cm = confusion_matrix(y_test, y_pred_manual)
# Set the figure size
plt.figure(figsize=(10, 7))

# Plot the heatmap
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')

# Add labels and title for clarity
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')

# Display the plot
plt.show()

# %%
def print_metrics(cm):
    # Unpack confusion matrix elements
    TP, FP = cm[0]
    FN, TN = cm[1]
    
    # Calculate metrics
    sensitivity = TP / (TP + FN)
    specificity = TN / (TN + FP)
    precision = TP / (TP + FP)
    npv = TN / (TN + FN)
    accuracy = (TP + TN) / (TP + FP + FN + TN)
    recall = sensitivity  # Recall is the same as sensitivity
    f_score = 2 * (precision * recall) / (precision + recall)
    
    print(f'''Tan, Megan, A20527707 solution:
Training set size: 80 %  

Training classifier…
Testing classifier…
Test results / metrics:

Number of true positives: {TP}
Number of true negatives: {TN}
Number of false positives: {FP}
Number of false negatives: {FN}
Sensitivity (recall): {sensitivity}
Specificity: {specificity}
Precision: {precision}
Negative predictive value: {npv}
Accuracy: {accuracy}
F-score: {f_score}
''')
print_metrics(cm)
# Out:
# Last Name, First Name, AXXXXXXXX solution:
# Training set size: 80 %
#
# Training classifier…
# Testing classifier…
# Test results / metrics:
#
# Number of true positives: 85
# Number of true negatives: 5946
# Number of false positives: 2494
# Number of false negatives: 4
# Sensitivity (recall): 0.9550561797752809
# Specificity: 0.7045023696682464
# Precision: 0.032958511050794885
# Negative predictive value: 0.999327731092437
# Accuracy: 0.7071168952983937
# F-score: 0.06371814092953525

# %%
def get_and_classify_user_input():
#     user_input = input("Please enter a sentence")
    user_input = "i hate disney"
    user_input_data = {user_input}
    user_input_df = pd.DataFrame(user_input_data)
    user_input_s_array = vectorizer.fit_transform(user_input_df[0])
#     user_input_s_array = string_to_sparse_array(user_input)
    return predict(user_input_s_array, probability_negative, probability_positive, likelihoods_negative, likelihoods_positive)

prediction = get_and_classify_user_input() 
prediction
# Out:
# array([1.])

# %%
# USING MULTINOMIALMB
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score

vectorizer = CountVectorizer()
X_train = vectorizer.fit_transform(training_set['Review_Text_No_Stopwords'])
y_train = training_set['Sentiment']
X_test = vectorizer.transform(test_set ["Review_Text_No_Stopwords"])
y_test = test_set['Sentiment']


model = MultinomialNB()

# Train the model
model.fit(X_train, y_train)

# Predict the test set results
y_pred = model.predict(X_test)

# Calculate and print the accuracy
accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy: {accuracy}')
# Out:
# Accuracy: 0.8446476726462657

# %%
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns
cm = confusion_matrix(y_test, y_pred)
# Set the figure size
plt.figure(figsize=(10, 7))

# Plot the heatmap
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')

# Add labels and title for clarity
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')

# Display the plot
plt.show()
